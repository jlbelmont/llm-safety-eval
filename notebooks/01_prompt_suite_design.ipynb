# %% [markdown]
# # 01 - Prompt Suite Design
#
# Inspect and extend prompt categories while keeping content non-operational.

# %%
from pathlib import Path
import yaml

prompt_path = Path('../prompts/prompt_suites.yaml')
suite = yaml.safe_load(prompt_path.read_text())
suite['categories'].keys()
